# %%
from pylabnet.utils.logging.logger import LogService
from pylabnet.network.core.generic_server import GenericServer

# %% [markdown]
# # Start Logging Server

# %%
log_service = LogService()

# %%
log_server = GenericServer(
    service=log_service, 
    host='localhost', 
    port=14785
)

# %%
log_server.start()
# Out:
# 2020-05-20 15:58:11,505 - INFO - server started on [127.0.0.1]:14785

# %%
log_server._server.active
# Out:
# True

# %% [markdown]
# # Monitor Clients and Logging Output

# %%
log_server._server.clients
# Out:
# set()

# %%
print ("Log messages will be displayed below")
# Out:
# Log messages will be displayed below
# 2020-05-20 15:58:27,627 - INFO - accepted ('127.0.0.1', 52684) with fd 1372
# 2020-05-20 15:58:27,629 - INFO - welcome ('127.0.0.1', 52684)
# 2020-05-20 15:58:27,634 - INFO - Client connected
# 2020-05-20 15:58:27,641 - INFO -  DAQ Log Server: Started logging
# 2020-05-20 15:58:30,015 - INFO -  DAQ Log Server: Successfully connected to NI DAQ 'cDAQ1Mod1' (type: NI 9264)
#
# 2020-05-20 15:58:36,635 - INFO -  DAQ Log Server: NiDaq cDAQ1Mod1 output ao2 successfully assigned to staticline Laser Green.
# 2020-05-20 15:58:36,636 - INFO -  DAQ Log Server: Setup of staticline Laser Green using module nidaqmx_card successful.
# 2020-05-20 15:59:25,579 - INFO - accepted ('127.0.0.1', 52776) with fd 1432
# 2020-05-20 15:59:25,581 - INFO - welcome ('127.0.0.1', 52776)
# 2020-05-20 15:59:25,585 - INFO - Client connected
# 2020-05-20 15:59:26,206 - DEBUG - Client disconnected
# 2020-05-20 15:59:26,208 - INFO - goodbye ('127.0.0.1', 52776)
# 2020-05-20 15:59:26,209 - INFO - accepted ('127.0.0.1', 52779) with fd 1456
# 2020-05-20 15:59:26,216 - INFO - welcome ('127.0.0.1', 52779)
# 2020-05-20 15:59:26,221 - INFO - Client connected
# 2020-05-20 15:59:38,546 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 15:59:39,254 - DEBUG - Client disconnected
# 2020-05-20 15:59:39,256 - INFO - goodbye ('127.0.0.1', 52779)
# 2020-05-20 15:59:39,257 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 15:59:39,264 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 15:59:45,544 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 15:59:45,549 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:00:23,362 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:00:24,063 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:00:24,067 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:04:07,791 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:04:08,484 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:04:08,490 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:04:25,183 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:04:25,184 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:05:10,638 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:05:11,271 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:05:11,277 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:21:53,920 - DEBUG - Client disconnected
# 2020-05-20 16:21:53,924 - INFO - goodbye ('127.0.0.1', 52684)
# 2020-05-20 16:21:59,849 - INFO - accepted ('127.0.0.1', 53310) with fd 1384
# 2020-05-20 16:21:59,851 - INFO - welcome ('127.0.0.1', 53310)
# 2020-05-20 16:21:59,856 - INFO - Client connected
# 2020-05-20 16:21:59,865 - INFO -  DAQ Log Server: Started logging
# 2020-05-20 16:22:02,501 - INFO -  DAQ Log Server: Successfully connected to NI DAQ 'cDAQ1Mod1' (type: NI 9264)
#
# 2020-05-20 16:22:03,816 - INFO -  DAQ Log Server: NiDaq cDAQ1Mod1 output ao2 successfully assigned to staticline Laser Green.
# 2020-05-20 16:22:03,818 - INFO -  DAQ Log Server: Setup of staticline Laser Green using module nidaqmx_card successful.
# 2020-05-20 16:27:03,810 - INFO - accepted ('127.0.0.1', 53414) with fd 1424
# 2020-05-20 16:27:03,814 - INFO - welcome ('127.0.0.1', 53414)
# 2020-05-20 16:27:03,822 - INFO - Client connected
# 2020-05-20 16:27:03,836 - INFO -  DAQ Log Server: Started logging
# 2020-05-20 16:27:04,510 - INFO -  DAQ Log Server: Successfully connected to NI DAQ 'cDAQ1Mod1' (type: NI 9264)
#
# 2020-05-20 16:27:05,509 - INFO -  DAQ Log Server: NiDaq cDAQ1Mod1 output ao2 successfully assigned to staticline Laser Green.
# 2020-05-20 16:27:05,511 - INFO -  DAQ Log Server: Setup of staticline Laser Green using module nidaqmx_card successful.
# 2020-05-20 16:28:05,093 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:28:05,691 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:28:05,696 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:28:23,111 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:28:24,194 - INFO -  DAQ Log Server: Client disconnected
# 2020-05-20 16:28:24,198 - INFO -  DAQ Log Server: Client connected
# 2020-05-20 16:28:24,964 - INFO -  DAQ Log Server: Staticline Laser Green set to high.
# 2020-05-20 16:28:28,994 - INFO -  DAQ Log Server: Staticline Laser Green set to low.
# 2020-05-20 16:28:30,799 - INFO -  DAQ Log Server: Staticline Laser Green set to high.
# 2020-05-20 16:31:34,973 - INFO - accepted ('127.0.0.1', 53593) with fd 1476
# 2020-05-20 16:31:34,975 - INFO - welcome ('127.0.0.1', 53593)
# 2020-05-20 16:31:34,979 - INFO - Client connected
# 2020-05-20 16:31:34,985 - INFO -  ZI HDAWG dev8040: Started logging
# 2020-05-20 16:31:45,294 - INFO -  ZI HDAWG dev8040: Discovered device `dev8040`: HDAWG8 with options MF, CNT, ME, PC, SKW.
# 2020-05-20 16:31:45,297 - INFO -  ZI HDAWG dev8040: Creating an API session for device `dev8040` on `127.0.0.1`, `8004` with apilevel `6`.
# 2020-05-20 16:31:45,300 - INFO -  ZI HDAWG dev8040: Will try to connect device `DEV8040` on interface 1GbE.
# 2020-05-20 16:31:46,321 - INFO -  ZI HDAWG dev8040: Disabled everything.
# 2020-05-20 16:31:46,332 - INFO -  ZI HDAWG dev8040: Set all DIO outputs to low.
# 2020-05-20 16:31:48,350 - INFO -  ZI HDAWG dev8040: Enabled wave output 0.
# 2020-05-20 16:31:48,361 - INFO -  ZI HDAWG dev8040: Enabled wave output 1.
# 2020-05-20 16:31:52,496 - INFO -  ZI HDAWG dev8040: Changed range of wave output 0 to 0.2 V.
# 2020-05-20 16:31:55,193 - INFO -  ZI HDAWG dev8040: Changed range of wave output 1 to 0.2 V.
# 2020-05-20 16:32:15,286 - INFO -  ZI HDAWG dev8040: AWG 0: Module created.
# 2020-05-20 16:32:15,293 - INFO -  ZI HDAWG dev8040: AWG 0: Changed sampling rate to 2.4 GHz.
# 2020-05-20 16:32:15,794 - INFO -  ZI HDAWG dev8040: Compilation successful with no warnings, will upload the program to the instrument.
# 2020-05-20 16:32:16,001 - INFO -  ZI HDAWG dev8040: 0 progress: 0.00
# 2020-05-20 16:32:16,205 - INFO -  ZI HDAWG dev8040: 1 progress: 1.00
# 2020-05-20 16:32:16,212 - INFO -  ZI HDAWG dev8040: Upload to the instrument successful.
# 2020-05-20 16:32:27,642 - INFO -  ZI HDAWG dev8040: AWG 0: Started.
# 2020-05-20 16:32:43,210 - INFO -  ZI HDAWG dev8040: AWG 0: Stopped.
# 2020-05-20 16:32:43,724 - INFO -  ZI HDAWG dev8040: Compilation successful with no warnings, will upload the program to the instrument.
# 2020-05-20 16:32:43,928 - INFO -  ZI HDAWG dev8040: 0 progress: 1.00
# 2020-05-20 16:32:43,934 - INFO -  ZI HDAWG dev8040: Upload to the instrument successful.
# 2020-05-20 16:32:49,703 - INFO -  ZI HDAWG dev8040: AWG 0: Started.
# 2020-05-20 16:32:54,876 - INFO -  ZI HDAWG dev8040: AWG 0: Stopped.
# 2020-05-20 16:33:00,056 - WARNING -  ZI HDAWG dev8040: Compilation successful with warnings, will upload the program to the instrument.
# 2020-05-20 16:33:00,059 - WARNING -  ZI HDAWG dev8040: Compiler warning: Compilation started
# Detected 1 devices with a total of 1 AWG cores.
# Compiling source string
# Warning (line: 2): using vect with more that 100 arguments is discouraged, use CSV files to define your waveforms instead
# Warning (line: 3): using vect with more that 100 arguments is discouraged, use CSV files to define your waveforms instead
#
# Uploading ELF file to device dev8040
# 2020-05-20 16:33:00,263 - INFO -  ZI HDAWG dev8040: 0 progress: 0.00
# 2020-05-20 16:33:00,465 - INFO -  ZI HDAWG dev8040: 1 progress: 1.00
# 2020-05-20 16:33:00,467 - INFO -  ZI HDAWG dev8040: Upload to the instrument successful.
# 2020-05-20 16:33:00,470 - INFO -  ZI HDAWG dev8040: AWG 0: Started.
# 2020-05-20 16:33:33,286 - INFO - accepted ('127.0.0.1', 53973) with fd 1268
# 2020-05-20 16:33:33,288 - INFO - welcome ('127.0.0.1', 53973)
# 2020-05-20 16:33:33,293 - INFO - Client connected
# 2020-05-20 16:33:33,300 - INFO -  ZI HDAWG dev8040: Started logging
# 2020-05-20 16:33:38,066 - INFO -  ZI HDAWG dev8040: Discovered device `dev8040`: HDAWG8 with options MF, CNT, ME, PC, SKW.
# 2020-05-20 16:33:38,069 - INFO -  ZI HDAWG dev8040: Creating an API session for device `dev8040` on `127.0.0.1`, `8004` with apilevel `6`.
# 2020-05-20 16:33:38,889 - INFO -  ZI HDAWG dev8040: Disabled everything.
# 2020-05-20 16:33:38,898 - INFO -  ZI HDAWG dev8040: Set all DIO outputs to low.
# 2020-05-20 16:33:42,258 - INFO -  ZI HDAWG dev8040: DIO_bit 1 successfully assigned to staticline Shutter.
# 2020-05-20 16:33:42,273 - INFO -  ZI HDAWG dev8040: Setup of staticline Shutter using module zi_hdawg successful.
# 2020-05-20 16:34:01,264 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:01,379 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:01,599 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:01,717 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:01,932 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:02,049 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:02,265 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:02,382 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:02,599 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:02,714 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:02,931 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:03,045 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:03,265 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:03,383 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:03,600 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:03,719 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:03,934 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:04,050 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:04,265 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:04,380 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:04,598 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:04,715 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:04,933 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:05,048 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:05,265 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:05,379 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:05,598 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:05,715 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:05,934 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:06,050 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:06,272 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:06,388 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:06,605 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:06,721 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:06,936 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:07,057 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:07,279 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:07,397 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:07,615 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:07,730 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:07,944 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:08,064 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:08,284 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:08,400 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:08,622 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:08,741 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:08,960 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:09,081 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:09,294 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:09,410 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:09,627 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:09,746 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:09,967 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:10,092 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:10,305 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:10,424 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:10,640 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:10,759 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:10,975 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:11,090 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:11,306 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:11,423 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:11,638 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:11,756 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:11,972 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:12,093 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:12,309 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:12,429 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:12,647 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:12,766 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:12,981 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:13,099 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:13,317 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:13,438 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:13,652 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:13,789 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:14,006 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:14,126 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:14,341 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:14,456 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:14,673 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:14,791 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:15,008 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:15,125 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:15,343 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:15,457 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:15,675 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:15,790 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:16,007 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:16,122 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:16,337 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:16,453 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:16,670 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:16,785 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:17,003 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:17,117 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:17,334 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to high.
# 2020-05-20 16:34:17,448 - INFO -  ZI HDAWG dev8040: Staticline Shutter set to low.
# 2020-05-20 16:34:22,187 - INFO -  ZI HDAWG dev8040: Set all DIO outputs to low.
# 2020-05-20 16:34:47,872 - INFO -  ZI HDAWG dev8040: Set all DIO outputs to low.
# 2020-05-20 16:34:47,875 - INFO -  ZI HDAWG dev8040: DIO_bit 0 successfully assigned to staticline DIO-0 HDAWG.
# 2020-05-20 16:34:47,893 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-0 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:47,896 - INFO -  ZI HDAWG dev8040: DIO_bit 1 successfully assigned to staticline DIO-1 HDAWG.
# 2020-05-20 16:34:47,914 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-1 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:47,917 - INFO -  ZI HDAWG dev8040: DIO_bit 2 successfully assigned to staticline DIO-2 HDAWG.
# 2020-05-20 16:34:47,935 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-2 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:47,937 - INFO -  ZI HDAWG dev8040: DIO_bit 3 successfully assigned to staticline DIO-3 HDAWG.
# 2020-05-20 16:34:47,952 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-3 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:47,954 - INFO -  ZI HDAWG dev8040: DIO_bit 4 successfully assigned to staticline DIO-4 HDAWG.
# 2020-05-20 16:34:47,968 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-4 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:47,970 - INFO -  ZI HDAWG dev8040: DIO_bit 5 successfully assigned to staticline DIO-5 HDAWG.
# 2020-05-20 16:34:47,984 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-5 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:47,987 - INFO -  ZI HDAWG dev8040: DIO_bit 6 successfully assigned to staticline DIO-6 HDAWG.
# 2020-05-20 16:34:48,000 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-6 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,003 - INFO -  ZI HDAWG dev8040: DIO_bit 7 successfully assigned to staticline DIO-7 HDAWG.
# 2020-05-20 16:34:48,018 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-7 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,020 - INFO -  ZI HDAWG dev8040: DIO_bit 8 successfully assigned to staticline DIO-8 HDAWG.
# 2020-05-20 16:34:48,032 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-8 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,035 - INFO -  ZI HDAWG dev8040: DIO_bit 9 successfully assigned to staticline DIO-9 HDAWG.
# 2020-05-20 16:34:48,049 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-9 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,052 - INFO -  ZI HDAWG dev8040: DIO_bit 10 successfully assigned to staticline DIO-10 HDAWG.
# 2020-05-20 16:34:48,065 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-10 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,067 - INFO -  ZI HDAWG dev8040: DIO_bit 11 successfully assigned to staticline DIO-11 HDAWG.
# 2020-05-20 16:34:48,081 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-11 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,084 - INFO -  ZI HDAWG dev8040: DIO_bit 12 successfully assigned to staticline DIO-12 HDAWG.
# 2020-05-20 16:34:48,096 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-12 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,099 - INFO -  ZI HDAWG dev8040: DIO_bit 13 successfully assigned to staticline DIO-13 HDAWG.
# 2020-05-20 16:34:48,112 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-13 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,115 - INFO -  ZI HDAWG dev8040: DIO_bit 14 successfully assigned to staticline DIO-14 HDAWG.
# 2020-05-20 16:34:48,128 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-14 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,131 - INFO -  ZI HDAWG dev8040: DIO_bit 15 successfully assigned to staticline DIO-15 HDAWG.
# 2020-05-20 16:34:48,145 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-15 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,148 - INFO -  ZI HDAWG dev8040: DIO_bit 16 successfully assigned to staticline DIO-16 HDAWG.
# 2020-05-20 16:34:48,161 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-16 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,163 - INFO -  ZI HDAWG dev8040: DIO_bit 17 successfully assigned to staticline DIO-17 HDAWG.
# 2020-05-20 16:34:48,176 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-17 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,179 - INFO -  ZI HDAWG dev8040: DIO_bit 18 successfully assigned to staticline DIO-18 HDAWG.
# 2020-05-20 16:34:48,191 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-18 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,194 - INFO -  ZI HDAWG dev8040: DIO_bit 19 successfully assigned to staticline DIO-19 HDAWG.
# 2020-05-20 16:34:48,209 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-19 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,212 - INFO -  ZI HDAWG dev8040: DIO_bit 20 successfully assigned to staticline DIO-20 HDAWG.
# 2020-05-20 16:34:48,233 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-20 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,236 - INFO -  ZI HDAWG dev8040: DIO_bit 21 successfully assigned to staticline DIO-21 HDAWG.
# 2020-05-20 16:34:48,254 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-21 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,257 - INFO -  ZI HDAWG dev8040: DIO_bit 22 successfully assigned to staticline DIO-22 HDAWG.
# 2020-05-20 16:34:48,269 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-22 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,272 - INFO -  ZI HDAWG dev8040: DIO_bit 23 successfully assigned to staticline DIO-23 HDAWG.
# 2020-05-20 16:34:48,286 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-23 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,289 - INFO -  ZI HDAWG dev8040: DIO_bit 24 successfully assigned to staticline DIO-24 HDAWG.
# 2020-05-20 16:34:48,301 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-24 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,303 - INFO -  ZI HDAWG dev8040: DIO_bit 25 successfully assigned to staticline DIO-25 HDAWG.
# 2020-05-20 16:34:48,318 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-25 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,321 - INFO -  ZI HDAWG dev8040: DIO_bit 26 successfully assigned to staticline DIO-26 HDAWG.
# 2020-05-20 16:34:48,336 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-26 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,338 - INFO -  ZI HDAWG dev8040: DIO_bit 27 successfully assigned to staticline DIO-27 HDAWG.
# 2020-05-20 16:34:48,357 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-27 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,359 - INFO -  ZI HDAWG dev8040: DIO_bit 28 successfully assigned to staticline DIO-28 HDAWG.
# 2020-05-20 16:34:48,375 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-28 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,377 - INFO -  ZI HDAWG dev8040: DIO_bit 29 successfully assigned to staticline DIO-29 HDAWG.
# 2020-05-20 16:34:48,395 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-29 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,398 - INFO -  ZI HDAWG dev8040: DIO_bit 30 successfully assigned to staticline DIO-30 HDAWG.
# 2020-05-20 16:34:48,413 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-30 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,415 - INFO -  ZI HDAWG dev8040: DIO_bit 31 successfully assigned to staticline DIO-31 HDAWG.
# 2020-05-20 16:34:48,429 - INFO -  ZI HDAWG dev8040: Setup of staticline DIO-31 HDAWG using module zi_hdawg successful.
# 2020-05-20 16:34:48,446 - INFO -  ZI HDAWG dev8040: Staticline DIO-0 HDAWG set to high.
# 2020-05-20 16:34:48,762 - INFO -  ZI HDAWG dev8040: Staticline DIO-1 HDAWG set to high.
# 2020-05-20 16:34:49,075 - INFO -  ZI HDAWG dev8040: Staticline DIO-2 HDAWG set to high.
# 2020-05-20 16:34:49,392 - INFO -  ZI HDAWG dev8040: Staticline DIO-3 HDAWG set to high.
# 2020-05-20 16:34:49,714 - INFO -  ZI HDAWG dev8040: Staticline DIO-4 HDAWG set to high.
# 2020-05-20 16:34:50,033 - INFO -  ZI HDAWG dev8040: Staticline DIO-5 HDAWG set to high.
# 2020-05-20 16:34:50,352 - INFO -  ZI HDAWG dev8040: Staticline DIO-6 HDAWG set to high.
# 2020-05-20 16:34:50,671 - INFO -  ZI HDAWG dev8040: Staticline DIO-7 HDAWG set to high.
# 2020-05-20 16:34:50,983 - INFO -  ZI HDAWG dev8040: Staticline DIO-8 HDAWG set to high.
# 2020-05-20 16:34:51,302 - INFO -  ZI HDAWG dev8040: Staticline DIO-9 HDAWG set to high.
# 2020-05-20 16:34:51,622 - INFO -  ZI HDAWG dev8040: Staticline DIO-10 HDAWG set to high.
# 2020-05-20 16:34:51,940 - INFO -  ZI HDAWG dev8040: Staticline DIO-11 HDAWG set to high.
# 2020-05-20 16:34:52,256 - INFO -  ZI HDAWG dev8040: Staticline DIO-12 HDAWG set to high.
# 2020-05-20 16:34:52,574 - INFO -  ZI HDAWG dev8040: Staticline DIO-13 HDAWG set to high.
# 2020-05-20 16:34:52,890 - INFO -  ZI HDAWG dev8040: Staticline DIO-14 HDAWG set to high.
# 2020-05-20 16:34:53,207 - INFO -  ZI HDAWG dev8040: Staticline DIO-15 HDAWG set to high.
# 2020-05-20 16:34:53,526 - INFO -  ZI HDAWG dev8040: Staticline DIO-16 HDAWG set to high.
# 2020-05-20 16:34:53,846 - INFO -  ZI HDAWG dev8040: Staticline DIO-17 HDAWG set to high.
# 2020-05-20 16:34:54,167 - INFO -  ZI HDAWG dev8040: Staticline DIO-18 HDAWG set to high.
# 2020-05-20 16:34:54,484 - INFO -  ZI HDAWG dev8040: Staticline DIO-19 HDAWG set to high.
# 2020-05-20 16:34:54,799 - INFO -  ZI HDAWG dev8040: Staticline DIO-20 HDAWG set to high.
# 2020-05-20 16:34:55,119 - INFO -  ZI HDAWG dev8040: Staticline DIO-21 HDAWG set to high.
# 2020-05-20 16:34:55,438 - INFO -  ZI HDAWG dev8040: Staticline DIO-22 HDAWG set to high.
# 2020-05-20 16:34:55,752 - INFO -  ZI HDAWG dev8040: Staticline DIO-23 HDAWG set to high.
# 2020-05-20 16:34:56,070 - INFO -  ZI HDAWG dev8040: Staticline DIO-24 HDAWG set to high.
# 2020-05-20 16:34:56,387 - INFO -  ZI HDAWG dev8040: Staticline DIO-25 HDAWG set to high.
# 2020-05-20 16:34:56,706 - INFO -  ZI HDAWG dev8040: Staticline DIO-26 HDAWG set to high.
# 2020-05-20 16:34:57,027 - INFO -  ZI HDAWG dev8040: Staticline DIO-27 HDAWG set to high.
# 2020-05-20 16:34:57,343 - INFO -  ZI HDAWG dev8040: Staticline DIO-28 HDAWG set to high.
# 2020-05-20 16:34:57,658 - INFO -  ZI HDAWG dev8040: Staticline DIO-29 HDAWG set to high.
# 2020-05-20 16:34:57,974 - INFO -  ZI HDAWG dev8040: Staticline DIO-30 HDAWG set to high.
# 2020-05-20 16:34:58,293 - INFO -  ZI HDAWG dev8040: Staticline DIO-31 HDAWG set to high.
# 2020-05-20 16:34:58,611 - INFO -  ZI HDAWG dev8040: Staticline DIO-31 HDAWG set to low.
# 2020-05-20 16:34:58,928 - INFO -  ZI HDAWG dev8040: Staticline DIO-31 HDAWG set to high.
# 2020-05-20 16:34:59,245 - INFO -  ZI HDAWG dev8040: Staticline DIO-30 HDAWG set to low.
# 2020-05-20 16:34:59,567 - INFO -  ZI HDAWG dev8040: Staticline DIO-30 HDAWG set to high.
# 2020-05-20 16:34:59,884 - INFO -  ZI HDAWG dev8040: Staticline DIO-29 HDAWG set to low.
# 2020-05-20 16:35:00,206 - INFO -  ZI HDAWG dev8040: Staticline DIO-29 HDAWG set to high.
# 2020-05-20 16:35:00,527 - INFO -  ZI HDAWG dev8040: Staticline DIO-28 HDAWG set to low.
# 2020-05-20 16:35:00,846 - INFO -  ZI HDAWG dev8040: Staticline DIO-28 HDAWG set to high.
# 2020-05-20 16:35:01,165 - INFO -  ZI HDAWG dev8040: Staticline DIO-27 HDAWG set to low.
# 2020-05-20 16:35:01,484 - INFO -  ZI HDAWG dev8040: Staticline DIO-27 HDAWG set to high.
# 2020-05-20 16:35:01,802 - INFO -  ZI HDAWG dev8040: Staticline DIO-26 HDAWG set to low.
# 2020-05-20 16:35:02,119 - INFO -  ZI HDAWG dev8040: Staticline DIO-26 HDAWG set to high.
# 2020-05-20 16:35:02,436 - INFO -  ZI HDAWG dev8040: Staticline DIO-25 HDAWG set to low.
# 2020-05-20 16:35:02,753 - INFO -  ZI HDAWG dev8040: Staticline DIO-25 HDAWG set to high.
# 2020-05-20 16:35:03,073 - INFO -  ZI HDAWG dev8040: Staticline DIO-24 HDAWG set to low.
# 2020-05-20 16:35:03,389 - INFO -  ZI HDAWG dev8040: Staticline DIO-24 HDAWG set to high.
# 2020-05-20 16:35:03,709 - INFO -  ZI HDAWG dev8040: Staticline DIO-23 HDAWG set to low.
# 2020-05-20 16:35:04,032 - INFO -  ZI HDAWG dev8040: Staticline DIO-23 HDAWG set to high.
# 2020-05-20 16:35:04,348 - INFO -  ZI HDAWG dev8040: Staticline DIO-22 HDAWG set to low.
# 2020-05-20 16:35:04,668 - INFO -  ZI HDAWG dev8040: Staticline DIO-22 HDAWG set to high.
# 2020-05-20 16:35:04,984 - INFO -  ZI HDAWG dev8040: Staticline DIO-21 HDAWG set to low.
# 2020-05-20 16:35:05,303 - INFO -  ZI HDAWG dev8040: Staticline DIO-21 HDAWG set to high.
# 2020-05-20 16:35:05,618 - INFO -  ZI HDAWG dev8040: Staticline DIO-20 HDAWG set to low.
# 2020-05-20 16:35:05,939 - INFO -  ZI HDAWG dev8040: Staticline DIO-20 HDAWG set to high.
# 2020-05-20 16:35:06,252 - INFO -  ZI HDAWG dev8040: Staticline DIO-19 HDAWG set to low.
# 2020-05-20 16:35:06,574 - INFO -  ZI HDAWG dev8040: Staticline DIO-19 HDAWG set to high.
# 2020-05-20 16:35:06,892 - INFO -  ZI HDAWG dev8040: Staticline DIO-18 HDAWG set to low.
# 2020-05-20 16:35:07,207 - INFO -  ZI HDAWG dev8040: Staticline DIO-18 HDAWG set to high.
# 2020-05-20 16:35:07,523 - INFO -  ZI HDAWG dev8040: Staticline DIO-17 HDAWG set to low.
# 2020-05-20 16:35:07,841 - INFO -  ZI HDAWG dev8040: Staticline DIO-17 HDAWG set to high.
# 2020-05-20 16:35:08,158 - INFO -  ZI HDAWG dev8040: Staticline DIO-16 HDAWG set to low.
# 2020-05-20 16:35:08,475 - INFO -  ZI HDAWG dev8040: Staticline DIO-16 HDAWG set to high.
# 2020-05-20 16:35:08,791 - INFO -  ZI HDAWG dev8040: Staticline DIO-15 HDAWG set to low.
# 2020-05-20 16:35:09,106 - INFO -  ZI HDAWG dev8040: Staticline DIO-15 HDAWG set to high.
# 2020-05-20 16:35:09,421 - INFO -  ZI HDAWG dev8040: Staticline DIO-14 HDAWG set to low.
# 2020-05-20 16:35:09,736 - INFO -  ZI HDAWG dev8040: Staticline DIO-14 HDAWG set to high.
# 2020-05-20 16:35:10,056 - INFO -  ZI HDAWG dev8040: Staticline DIO-13 HDAWG set to low.
# 2020-05-20 16:35:10,371 - INFO -  ZI HDAWG dev8040: Staticline DIO-13 HDAWG set to high.
# 2020-05-20 16:35:10,687 - INFO -  ZI HDAWG dev8040: Staticline DIO-12 HDAWG set to low.
# 2020-05-20 16:35:11,003 - INFO -  ZI HDAWG dev8040: Staticline DIO-12 HDAWG set to high.
# 2020-05-20 16:35:11,319 - INFO -  ZI HDAWG dev8040: Staticline DIO-11 HDAWG set to low.
# 2020-05-20 16:35:11,635 - INFO -  ZI HDAWG dev8040: Staticline DIO-11 HDAWG set to high.
# 2020-05-20 16:35:11,948 - INFO -  ZI HDAWG dev8040: Staticline DIO-10 HDAWG set to low.
# 2020-05-20 16:35:12,263 - INFO -  ZI HDAWG dev8040: Staticline DIO-10 HDAWG set to high.
# 2020-05-20 16:35:12,582 - INFO -  ZI HDAWG dev8040: Staticline DIO-9 HDAWG set to low.
# 2020-05-20 16:35:12,899 - INFO -  ZI HDAWG dev8040: Staticline DIO-9 HDAWG set to high.
# 2020-05-20 16:35:13,213 - INFO -  ZI HDAWG dev8040: Staticline DIO-8 HDAWG set to low.
# 2020-05-20 16:35:13,535 - INFO -  ZI HDAWG dev8040: Staticline DIO-8 HDAWG set to high.
# 2020-05-20 16:35:13,856 - INFO -  ZI HDAWG dev8040: Staticline DIO-7 HDAWG set to low.
# 2020-05-20 16:35:14,174 - INFO -  ZI HDAWG dev8040: Staticline DIO-7 HDAWG set to high.
# 2020-05-20 16:35:14,494 - INFO -  ZI HDAWG dev8040: Staticline DIO-6 HDAWG set to low.
# 2020-05-20 16:35:14,806 - INFO -  ZI HDAWG dev8040: Staticline DIO-6 HDAWG set to high.
# 2020-05-20 16:35:15,125 - INFO -  ZI HDAWG dev8040: Staticline DIO-5 HDAWG set to low.
# 2020-05-20 16:35:15,443 - INFO -  ZI HDAWG dev8040: Staticline DIO-5 HDAWG set to high.
# 2020-05-20 16:35:15,760 - INFO -  ZI HDAWG dev8040: Staticline DIO-4 HDAWG set to low.
# 2020-05-20 16:35:16,076 - INFO -  ZI HDAWG dev8040: Staticline DIO-4 HDAWG set to high.
# 2020-05-20 16:35:16,395 - INFO -  ZI HDAWG dev8040: Staticline DIO-3 HDAWG set to low.
# 2020-05-20 16:35:16,714 - INFO -  ZI HDAWG dev8040: Staticline DIO-3 HDAWG set to high.
# 2020-05-20 16:35:17,030 - INFO -  ZI HDAWG dev8040: Staticline DIO-2 HDAWG set to low.
# 2020-05-20 16:35:17,347 - INFO -  ZI HDAWG dev8040: Staticline DIO-2 HDAWG set to high.
# 2020-05-20 16:35:17,662 - INFO -  ZI HDAWG dev8040: Staticline DIO-1 HDAWG set to low.
# 2020-05-20 16:35:17,979 - INFO -  ZI HDAWG dev8040: Staticline DIO-1 HDAWG set to high.
# 2020-05-20 16:35:18,294 - INFO -  ZI HDAWG dev8040: Staticline DIO-0 HDAWG set to low.
# 2020-05-20 16:35:18,607 - INFO -  ZI HDAWG dev8040: Staticline DIO-0 HDAWG set to high.
# 2020-05-20 16:35:18,915 - INFO -  ZI HDAWG dev8040: Set all DIO outputs to low.
