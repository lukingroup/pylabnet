# %%
from windfreak import SynthHD
from pylabnet.utils.logging.logger import LogHandler

# %%
synth = SynthHD('COM7')
synth.init()

# %%
# Set channel 0 power and frequency
synth[0].power = 13.5
synth[0].frequency =200e6

# Enable channel 0
synth[0].enable = True

# %%
synth.trigger_mode
# Out:
# 'rf enable'

# %%
synth.trigger_mode = 'rf enable'
