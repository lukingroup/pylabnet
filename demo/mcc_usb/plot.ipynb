# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("cooldown_PD.txt") as f:
    data = f.readlines()
data = [list(map(float, line.split(",")[1:])) for line in data]
data = np.array(data)

# %%
plt.plot(data[:, 0])
plt.plot(data[:, 1])
plt.show()
