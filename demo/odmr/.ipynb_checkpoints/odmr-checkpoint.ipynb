# %%
# Log client
from pylabnet.utils.logging.logger import LogClient

# %%
# Hardware clients
from pylabnet.hardware.p_gen.ni_hsdio import ni654x_spgen
from pylabnet.hardware.cw_mw.rs import rs_smc
from pylabnet.hardware.counter.swabian_instruments import gated_ctr

# %%
# ODMR script
from pylabnet.scripts.odmr import ODMR
# GUI
from pylabnet.gui.igui.iplot import ComboTraceHMapPBar

# %% [markdown]
# ## Connect to devices

# %%
p_gen = ni654x_spgen.Client(host='localhost', port=1)

# %%
# p_gen.connect()
# Out:
# 0

# %%
mw_src = rs_smc.Client(host='localhost', port=2)

# %%
# mw_src.connect()
# Out:
# 0

# %%
gated_ctr = gated_ctr.Client(host='localhost', port=3)

# %%
# gated_ctr.connect()
# Out:
# 0

# %% [markdown]
# ## GUI

# %%
gui = ComboTraceHMapPBar(trace_title='Average', hm_title='All sweeps')

# %% [markdown]
# ## ODMR class

# %%
my_odmr = ODMR()

# %% [markdown]
# ### set_hardware()

# %%
my_odmr.set_hardware(
    gated_ctr=gated_ctr, 
    mw_src=mw_src, 
    p_gen=p_gen
)
# Out:
# 0

# %% [markdown]
# ### set_gui()

# %%
my_odmr.set_gui(
    trace=gui.trace_fig, 
    heat_map=gui.hm_fig, 
    p_bar=gui.p_bar
)
# Out:
# 0

# %% [markdown]
# ## Measurement

# %% [markdown]
# ### set_params()

# %%
my_odmr.set_params(
    start_f=2.8e9, 
    stop_f=2.95e9, 
    n_pts=250, 
    n_swps=1000, 
    mw_pwr=-15,  # -15
    accum_dur=0.01
)
# Out:
# 0

# %% [markdown]
# ### run()

# %%
my_odmr.clear_data()
# Out:
# 0

# %%
my_odmr.run()
# Out:
# 0

# %%
gui.show()
# Out:
# VBox(children=(HBox(children=(FigureWidget({
#     'data': [{'mode': 'lines',
#               'type': 'scatter',
#  …
