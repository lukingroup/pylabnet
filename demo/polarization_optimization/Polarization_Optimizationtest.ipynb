# %%
import pyvisa
from pylabnet.utils.logging.logger import LogClient
from pylabnet.network.core.generic_server import GenericServer
from pylabnet.hardware.power_meter.thorlabs_pm320e import Driver
from pylabnet.hardware.polarization.polarization_control import Driver as MPC320 , paddle1, paddle2, paddle3
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gpib_addres = 'USB0::0x1313::0x8022::M00579698::INSTR'

# Instantiate
logger = LogClient(
    host='139.180.129.96',
    port=6924,
    module_tag='Polarization Optimizer'
)

power_meter = Driver(
    gpib_address=gpib_addres, 
    logger=logger
)

# %%
power_meter.set_range(2,'R100NW')

pol_paddle = MPC320(b'38154354') #device = '38154354' #dummy setup

# Output of pol. paddle is connected to output 2 of powermeter
channel = 2
init_power = power_meter.get_power(channel)

print(f"Initial power is {init_power} W.")
# Out:
# There are 1 devices connected
# Device list created succesfully
# Connected to device 38154354,
# Description:  b'Polarization Controller'
# Serial No:  b'38154354'
# Motor Type:  6553856
# USB PID:  1727607224
# Max Number of Paddles:  1
# Initial power is 1.32370923e-08 W.

# %%
paddles = [paddle1, paddle3, paddle2]
pol_paddle.open()

velocity = 100 #percentage from 0 to 100
pol_paddle.set_velocity(velocity)

for paddle in paddles:
    home = pol_paddle.home(paddle)
    move = pol_paddle.move(paddle, 85)
# Out:
# Connected succesfully to device

# %%
stepnum = 25 #number of dtep angles within range
count = 0
itercount = 0
ang = [] 
angle = []
power = []
pos = []
iterationnum = 40
ang_paddles = []
power_paddles = []

# %%
for paddle in paddles:
    deviate = 170 #range of angle to scan
    stepsize = deviate/stepnum
    move_in = pol_paddle.move_rel(paddle, -deviate/2)
    while itercount < iterationnum:
        
        if itercount >= 1:
            move = pol_paddle.move(paddle, ang[itercount-1]-deviate/2)
        while count < stepnum:
            mover = pol_paddle.move_rel(paddle, stepsize)
            PosF = pol_paddle.get_angle(paddle)
            print(f"itercount = {itercount} count = {count}")
            print(f"Position after move relative is {PosF}") 
            current_power = power_meter.get_power(channel)
            print(f"Current power is {current_power} W.")
            power.extend([current_power])
            angle.extend([PosF])
            count += 1
        
        plt.title(f"paddle # {paddle.value} , iteration # {itercount}.")
        plt.plot(angle, power, "or")
        plt.show()
        maxindex = np.argmax(power)
        ang.extend([angle[maxindex]]) 
        if itercount >= 1:
            if abs(ang[itercount] - ang[itercount-1]) < 0.05:
                print(f"converged to max power.")
                move = pol_paddle.move(paddle, angle[maxindex])
                count = 0
                itercount = 0
                power = []
                angle = []
                break

        deviate = deviate/2
        stepsize = deviate/stepnum
        itercount += 1
        count = 0

    ang_paddles.extend(ang)
    power_paddles.extend(power)
    ang = []
    itercount = 0
    
PosF1 = pol_paddle.get_angle(paddles[0])
print(f"paddle = {paddles[0]} final_angle = {PosF1}")
PosF2 = pol_paddle.get_angle(paddles[1])
print(f"paddle = {paddles[1]} final_angle = {PosF2}")
PosF3 = pol_paddle.get_angle(paddles[2])
print(f"paddle = {paddles[2]} final_angle = {PosF3}")
# Out:
# itercount = 0 count = 1
# Position after move relative is 85.0
# Current power is 6.56291377e-09 W.
# itercount = 0 count = 2
# Position after move relative is 91.82481751824818
# Current power is 5.79432413e-09 W.
# itercount = 0 count = 3
# Position after move relative is 98.64963503649635
# Current power is 6.4877046e-09 W.
# itercount = 0 count = 4
# Position after move relative is 105.35036496350365
# Current power is 7.88786192e-09 W.
# itercount = 0 count = 5
# Position after move relative is 112.17518248175183
# Current power is 1.0313145e-08 W.
# itercount = 0 count = 6
# Position after move relative is 119.0
# Current power is 1.19389387e-08 W.
# itercount = 0 count = 7
# Position after move relative is 125.82481751824818
# Current power is 1.65453375e-08 W.
# itercount = 0 count = 8
# Position after move relative is 132.64963503649636
# Current power is 1.85481994e-08 W.
# itercount = 0 count = 9
# Position after move relative is 139.35036496350367
# Current power is 1.97824939e-08 W.
# itercount = 0 count = 10
# Position after move relative is 146.17518248175182
# Current power is 1.91230978e-08 W.
# itercount = 0 count = 11
# Position after move relative is 153.0
# Current power is 1.74210832e-08 W.
# itercount = 0 count = 12
# Position after move relative is 159.82481751824818
# Current power is 1.59086131e-08 W.
# itercount = 0 count = 13
# Position after move relative is 166.64963503649636
# Current power is 1.48402126e-08 W.
# itercount = 0 count = 14
# Position after move relative is 170.0
# Current power is 1.48659662e-08 W.
# itercount = 0 count = 15
# Position after move relative is 170.0
# Current power is 1.48865729e-08 W.
# itercount = 0 count = 16
# Position after move relative is 170.0
# Current power is 1.49277923e-08 W.
# itercount = 0 count = 17
# Position after move relative is 170.0
# Current power is 1.32432794e-08 W.
# itercount = 0 count = 18
# Position after move relative is 170.0
# Current power is 1.34081164e-08 W.
# itercount = 0 count = 19
# Position after move relative is 170.0
# Current power is 1.48742085e-08 W.
# itercount = 0 count = 20
# Position after move relative is 170.0
# Current power is 1.4973125e-08 W.
# itercount = 0 count = 21
# Position after move relative is 170.0
# Current power is 1.48876058e-08 W.
# itercount = 0 count = 22
# Position after move relative is 170.0
# Current power is 1.51987578e-08 W.
# itercount = 0 count = 23
# Position after move relative is 170.0
# Current power is 1.49648809e-08 W.
# itercount = 0 count = 24
# Position after move relative is 170.0
# Current power is 1.35915066e-08 W.
# itercount = 1 count = 0
# Position after move relative is 96.91240875912409
# Current power is 5.75002668e-09 W.
# itercount = 1 count = 1
# Position after move relative is 100.26277372262774
# Current power is 5.88498894e-09 W.
# itercount = 1 count = 2
# Position after move relative is 103.61313868613139
# Current power is 6.64019062e-09 W.
# itercount = 1 count = 3
# Position after move relative is 107.08759124087591
# Current power is 6.92146074e-09 W.
# itercount = 1 count = 4
# Position after move relative is 110.43795620437956
# Current power is 8.34015701e-09 W.
# itercount = 1 count = 5
# Position after move relative is 113.91240875912409
# Current power is 9.47140677e-09 W.
# itercount = 1 count = 6
# Position after move relative is 117.26277372262774
# Current power is 1.08787725e-08 W.
# itercount = 1 count = 7
# Position after move relative is 120.61313868613139
# Current power is 1.26508644e-08 W.
# itercount = 1 count = 8
# Position after move relative is 124.08759124087591
# Current power is 1.33947324e-08 W.
# itercount = 1 count = 9
# Position after move relative is 127.43795620437956
# Current power is 1.57211115e-08 W.
# itercount = 1 count = 10
# Position after move relative is 130.9124087591241
# Current power is 1.69667178e-08 W.
# itercount = 1 count = 11
# Position after move relative is 134.26277372262774
# Current power is 1.79897963e-08 W.
# itercount = 1 count = 12
# Position after move relative is 137.61313868613138
# Current power is 1.89943119e-08 W.
# itercount = 1 count = 13
# Position after move relative is 141.08759124087592
# Current power is 1.9031404e-08 W.
# itercount = 1 count = 14
# Position after move relative is 144.43795620437956
# Current power is 1.9113827e-08 W.
# itercount = 1 count = 15
# Position after move relative is 147.9124087591241
# Current power is 1.83689295e-08 W.
# itercount = 1 count = 16
# Position after move relative is 151.26277372262774
# Current power is 1.93662562e-08 W.
# itercount = 1 count = 17
# Position after move relative is 154.61313868613138
# Current power is 1.83854265e-08 W.
# itercount = 1 count = 18
# Position after move relative is 158.08759124087592
# Current power is 1.75879808e-08 W.
# itercount = 1 count = 19
# Position after move relative is 161.43795620437956
# Current power is 1.63969709e-08 W.
# itercount = 1 count = 20
# Position after move relative is 164.9124087591241
# Current power is 1.41334429e-08 W.
# itercount = 1 count = 21
# Position after move relative is 168.26277372262774
# Current power is 1.48556669e-08 W.
# itercount = 1 count = 22
# Position after move relative is 170.0
# Current power is 1.49102721e-08 W.
# itercount = 1 count = 23
# Position after move relative is 170.0
# Current power is 1.49483927e-08 W.
# itercount = 1 count = 24
# Position after move relative is 170.0
# Current power is 1.4913363e-08 W.
# converged to max power.
# itercount = 0 count = 0
# Position after move relative is 0.0
# Current power is 1.8523485e-08 W.
# itercount = 0 count = 1
# Position after move relative is 6.824817518248175
# Current power is 1.91014742e-08 W.
# itercount = 0 count = 2
# Position after move relative is 13.64963503649635
# Current power is 1.85708764e-08 W.
# itercount = 0 count = 3
# Position after move relative is 20.35036496350365
# Current power is 1.67596337e-08 W.
# itercount = 0 count = 4
# Position after move relative is 27.175182481751825
# Current power is 1.70779906e-08 W.
# itercount = 0 count = 5
# Position after move relative is 34.0
# Current power is 1.65236962e-08 W.
# itercount = 0 count = 6
# Position after move relative is 40.824817518248175
# Current power is 1.62918834e-08 W.
# itercount = 0 count = 7
# Position after move relative is 47.64963503649635
# Current power is 1.64052114e-08 W.
# itercount = 0 count = 8
# Position after move relative is 54.35036496350365
# Current power is 1.68739938e-08 W.
# itercount = 0 count = 9
# Position after move relative is 61.175182481751825
# Current power is 1.76425843e-08 W.
# itercount = 0 count = 10
# Position after move relative is 68.0
# Current power is 1.76199109e-08 W.
# itercount = 0 count = 11
# Position after move relative is 74.82481751824818
# Current power is 1.90478939e-08 W.
# itercount = 0 count = 12
# Position after move relative is 81.64963503649635
# Current power is 1.86069276e-08 W.
# itercount = 0 count = 13
# Position after move relative is 88.35036496350365
# Current power is 1.74231332e-08 W.
# itercount = 0 count = 14
# Position after move relative is 95.17518248175183
# Current power is 1.57097784e-08 W.
# itercount = 0 count = 15
# Position after move relative is 102.0
# Current power is 1.28527997e-08 W.
# itercount = 0 count = 16
# Position after move relative is 108.82481751824818
# Current power is 1.06438716e-08 W.
# itercount = 0 count = 17
# Position after move relative is 115.64963503649635
# Current power is 7.49119966e-09 W.
# itercount = 0 count = 18
# Position after move relative is 122.35036496350365
# Current power is 4.90313168e-09 W.
# itercount = 0 count = 19
# Position after move relative is 129.17518248175182
# Current power is 2.56129873e-09 W.
# itercount = 0 count = 20
# Position after move relative is 136.0
# Current power is 3.1734021e-10 W.
# itercount = 0 count = 21
# Position after move relative is 142.82481751824818
# Current power is 5.90362703e-10 W.
# itercount = 0 count = 22
# Position after move relative is 149.64963503649636
# Current power is 4.08817558e-09 W.
# itercount = 0 count = 23
# Position after move relative is 156.35036496350367
# Current power is 7.56126095e-09 W.
# itercount = 0 count = 24
# Position after move relative is 163.17518248175182
# Current power is 1.16545804e-08 W.
# itercount = 1 count = 0
# Position after move relative is 170.0
# Current power is 1.02276339e-08 W.
# itercount = 1 count = 1
# Position after move relative is 170.0
# Current power is 1.03522986e-08 W.
# itercount = 1 count = 2
# Position after move relative is 170.0
# Current power is 1.18709371e-08 W.
# itercount = 1 count = 3
# Position after move relative is 170.0
# Current power is 1.17225785e-08 W.
# itercount = 1 count = 4
# Position after move relative is 170.0
# Current power is 1.18070567e-08 W.
# itercount = 1 count = 5
# Position after move relative is 170.0
# Current power is 1.18080941e-08 W.
# itercount = 1 count = 6
# Position after move relative is 170.0
# Current power is 1.18884467e-08 W.
# itercount = 1 count = 7
# Position after move relative is 170.0
# Current power is 1.17710002e-08 W.
# itercount = 1 count = 8
# Position after move relative is 170.0
# Current power is 1.00803046e-08 W.
# itercount = 1 count = 9
# Position after move relative is 170.0
# Current power is 1.04388427e-08 W.
# itercount = 1 count = 10
# Position after move relative is 170.0
# Current power is 1.14433636e-08 W.
# itercount = 1 count = 11
# Position after move relative is 170.0
# Current power is 1.17256675e-08 W.
# itercount = 1 count = 12
# Position after move relative is 170.0
# Current power is 1.18997825e-08 W.
# itercount = 1 count = 13
# Position after move relative is 170.0
# Current power is 1.17122649e-08 W.
# itercount = 1 count = 14
# Position after move relative is 170.0
# Current power is 1.17751267e-08 W.
# itercount = 1 count = 15
# Position after move relative is 170.0
# Current power is 1.19203909e-08 W.
# itercount = 1 count = 16
# Position after move relative is 170.0
# Current power is 1.17998509e-08 W.
# itercount = 1 count = 17
# Position after move relative is 170.0
# Current power is 1.04790256e-08 W.
# itercount = 1 count = 18
# Position after move relative is 170.0
# Current power is 1.18668195e-08 W.
# itercount = 1 count = 19
# Position after move relative is 170.0
# Current power is 1.05727844e-08 W.
# itercount = 1 count = 20
# Position after move relative is 170.0
# Current power is 1.18214807e-08 W.
# itercount = 1 count = 21
# Position after move relative is 170.0
# Current power is 1.18565149e-08 W.
# itercount = 1 count = 22
# Position after move relative is 170.0
# Current power is 1.18493002e-08 W.
# itercount = 1 count = 23
# Position after move relative is 170.0
# Current power is 1.18493002e-08 W.
# itercount = 1 count = 24
# Position after move relative is 170.0
# Current power is 1.18966996e-08 W.
# converged to max power.
# itercount = 0 count = 0
# Position after move relative is 0.0
# Current power is 1.76580404e-08 W.
# itercount = 0 count = 1
# Position after move relative is 6.824817518248175
# Current power is 1.86934734e-08 W.
# itercount = 0 count = 2
# Position after move relative is 13.64963503649635
# Current power is 1.809385e-08 W.
# itercount = 0 count = 3
# Position after move relative is 20.35036496350365
# Current power is 1.51420849e-08 W.
# itercount = 0 count = 4
# Position after move relative is 27.175182481751825
# Current power is 1.24880737e-08 W.
# itercount = 0 count = 5
# Position after move relative is 34.0
# Current power is 1.05593827e-08 W.
# itercount = 0 count = 6
# Position after move relative is 40.824817518248175
# Current power is 7.8858049e-09 W.
# itercount = 0 count = 7
# Position after move relative is 47.64963503649635
# Current power is 6.33625952e-09 W.
# itercount = 0 count = 8
# Position after move relative is 54.35036496350365
# Current power is 6.45988685e-09 W.
# itercount = 0 count = 9
# Position after move relative is 61.175182481751825
# Current power is 7.54786278e-09 W.
# itercount = 0 count = 10
# Position after move relative is 68.0
# Current power is 8.11452772e-09 W.
# itercount = 0 count = 11
# Position after move relative is 74.82481751824818
# Current power is 1.25272281e-08 W.
# itercount = 0 count = 12
# Position after move relative is 81.64963503649635
# Current power is 1.50843924e-08 W.
# itercount = 0 count = 13
# Position after move relative is 88.35036496350365
# Current power is 1.77054265e-08 W.
# itercount = 0 count = 14
# Position after move relative is 95.17518248175183
# Current power is 1.91014742e-08 W.
# itercount = 0 count = 15
# Position after move relative is 102.0
# Current power is 1.86089881e-08 W.
# itercount = 0 count = 16
# Position after move relative is 108.82481751824818
# Current power is 1.80825221e-08 W.
# itercount = 0 count = 17
# Position after move relative is 115.64963503649635
# Current power is 1.52925104e-08 W.
# itercount = 0 count = 18
# Position after move relative is 122.35036496350365
# Current power is 1.19986945e-08 W.
# itercount = 0 count = 19
# Position after move relative is 129.17518248175182
# Current power is 8.23197599e-09 W.
# itercount = 0 count = 20
# Position after move relative is 136.0
# Current power is 4.70840344e-09 W.
# itercount = 0 count = 21
# Position after move relative is 142.82481751824818
# Current power is 1.81949245e-09 W.
# itercount = 0 count = 22
# Position after move relative is 149.64963503649636
# Current power is 2.93014302e-09 W.
# itercount = 0 count = 23
# Position after move relative is 156.35036496350367
# Current power is 4.58374183e-09 W.
# itercount = 0 count = 24
# Position after move relative is 163.17518248175182
# Current power is 7.76216691e-09 W.
# itercount = 1 count = 0
# Position after move relative is 52.737226277372265
# Current power is 4.58580374e-09 W.
# itercount = 1 count = 1
# Position after move relative is 56.087591240875916
# Current power is 6.12814066e-09 W.
# itercount = 1 count = 2
# Position after move relative is 59.43795620437956
# Current power is 6.62164013e-09 W.
# itercount = 1 count = 3
# Position after move relative is 62.91240875912409
# Current power is 7.24187599e-09 W.
# itercount = 1 count = 4
# Position after move relative is 66.26277372262774
# Current power is 8.13100876e-09 W.
# itercount = 1 count = 5
# Position after move relative is 69.73722627737226
# Current power is 7.77350007e-09 W.
# itercount = 1 count = 6
# Position after move relative is 73.08759124087591
# Current power is 1.01792104e-08 W.
# itercount = 1 count = 7
# Position after move relative is 76.43795620437956
# Current power is 1.03399298e-08 W.
# itercount = 1 count = 8
# Position after move relative is 79.91240875912409
# Current power is 1.35348461e-08 W.
# itercount = 1 count = 9
# Position after move relative is 83.26277372262774
# Current power is 1.44435539e-08 W.
# itercount = 1 count = 10
# Position after move relative is 86.73722627737226
# Current power is 1.60518265e-08 W.
# itercount = 1 count = 11
# Position after move relative is 90.08759124087591
# Current power is 1.70099916e-08 W.
# itercount = 1 count = 12
# Position after move relative is 93.43795620437956
# Current power is 1.7687924e-08 W.
# itercount = 1 count = 13
# Position after move relative is 96.91240875912409
# Current power is 1.89263147e-08 W.
# itercount = 1 count = 14
# Position after move relative is 100.26277372262774
# Current power is 1.9213763e-08 W.
# itercount = 1 count = 15
# Position after move relative is 103.73722627737227
# Current power is 1.92992822e-08 W.
# itercount = 1 count = 16
# Position after move relative is 107.08759124087591
# Current power is 1.88758431e-08 W.
# itercount = 1 count = 17
# Position after move relative is 110.43795620437956
# Current power is 1.80134823e-08 W.
# itercount = 1 count = 18
# Position after move relative is 113.91240875912409
# Current power is 1.70532566e-08 W.
# itercount = 1 count = 19
# Position after move relative is 117.26277372262774
# Current power is 1.44394319e-08 W.
# itercount = 1 count = 20
# Position after move relative is 120.73722627737227
# Current power is 1.4571313e-08 W.
# itercount = 1 count = 21
# Position after move relative is 124.08759124087591
# Current power is 1.26951685e-08 W.
# itercount = 1 count = 22
# Position after move relative is 127.43795620437956
# Current power is 1.08519833e-08 W.
# itercount = 1 count = 23
# Position after move relative is 130.9124087591241
# Current power is 9.38383682e-09 W.
# itercount = 1 count = 24
# Position after move relative is 134.26277372262774
# Current power is 7.42629469e-09 W.
# itercount = 2 count = 0
# Position after move relative is 82.51824817518248
# Current power is 1.34977576e-08 W.
# itercount = 2 count = 1
# Position after move relative is 84.13138686131387
# Current power is 1.42560541e-08 W.
# itercount = 2 count = 2
# Position after move relative is 85.86861313868613
# Current power is 1.50493609e-08 W.
# itercount = 2 count = 3
# Position after move relative is 87.6058394160584
# Current power is 1.40304088e-08 W.
# itercount = 2 count = 4
# Position after move relative is 89.34306569343066
# Current power is 1.51565107e-08 W.
# itercount = 2 count = 5
# Position after move relative is 90.95620437956205
# Current power is 1.70347221e-08 W.
# itercount = 2 count = 6
# Position after move relative is 92.69343065693431
# Current power is 1.76219856e-08 W.
# itercount = 2 count = 7
# Position after move relative is 94.43065693430657
# Current power is 1.75416197e-08 W.
# itercount = 2 count = 8
# Position after move relative is 96.04379562043796
# Current power is 1.84544486e-08 W.
# itercount = 2 count = 9
# Position after move relative is 97.78102189781022
# Current power is 1.84132407e-08 W.
# itercount = 2 count = 10
# Position after move relative is 99.51824817518248
# Current power is 1.91406073e-08 W.
# itercount = 2 count = 11
# Position after move relative is 101.13138686131387
# Current power is 1.7831125e-08 W.
# itercount = 2 count = 12
# Position after move relative is 102.86861313868613
# Current power is 1.93817087e-08 W.
# itercount = 2 count = 13
# Position after move relative is 104.6058394160584
# Current power is 1.93847889e-08 W.
# itercount = 2 count = 14
# Position after move relative is 106.34306569343066
# Current power is 1.91931679e-08 W.
# itercount = 2 count = 15
# Position after move relative is 107.95620437956205
# Current power is 1.92271514e-08 W.
# itercount = 2 count = 16
# Position after move relative is 109.69343065693431
# Current power is 1.88191756e-08 W.
# itercount = 2 count = 17
# Position after move relative is 111.43065693430657
# Current power is 1.67802412e-08 W.
# itercount = 2 count = 18
# Position after move relative is 113.04379562043796
# Current power is 1.79527007e-08 W.
# itercount = 2 count = 19
# Position after move relative is 114.78102189781022
# Current power is 1.74622929e-08 W.
# itercount = 2 count = 20
# Position after move relative is 116.51824817518248
# Current power is 1.71150827e-08 W.
# itercount = 2 count = 21
# Position after move relative is 118.13138686131387
# Current power is 1.60631668e-08 W.
# itercount = 2 count = 22
# Position after move relative is 119.86861313868613
# Current power is 1.40170187e-08 W.
# itercount = 2 count = 23
# Position after move relative is 121.6058394160584
# Current power is 1.3417389e-08 W.
# itercount = 2 count = 24
# Position after move relative is 123.34306569343066
# Current power is 1.39119374e-08 W.
# itercount = 3 count = 0
# Position after move relative is 93.93430656934306
# Current power is 1.77579764e-08 W.
# itercount = 3 count = 1
# Position after move relative is 94.8029197080292
# Current power is 1.79640267e-08 W.
# itercount = 3 count = 2
# Position after move relative is 95.67153284671534
# Current power is 1.76446449e-08 W.
# itercount = 3 count = 3
# Position after move relative is 96.54014598540147
# Current power is 1.82937203e-08 W.
# itercount = 3 count = 4
# Position after move relative is 97.4087591240876
# Current power is 1.84204563e-08 W.
# itercount = 3 count = 5
# Position after move relative is 98.27737226277372
# Current power is 1.89603249e-08 W.
# itercount = 3 count = 6
# Position after move relative is 99.02189781021897
# Current power is 1.86873006e-08 W.
# itercount = 3 count = 7
# Position after move relative is 99.89051094890512
# Current power is 1.90551059e-08 W.
# itercount = 3 count = 8
# Position after move relative is 100.75912408759125
# Current power is 1.91437017e-08 W.
# itercount = 3 count = 9
# Position after move relative is 101.62773722627738
# Current power is 1.92209875e-08 W.
# itercount = 3 count = 10
# Position after move relative is 102.4963503649635
# Current power is 1.94579393e-08 W.
# itercount = 3 count = 11
# Position after move relative is 103.36496350364963
# Current power is 1.93641814e-08 W.
# itercount = 3 count = 12
# Position after move relative is 104.23357664233576
# Current power is 1.93672776e-08 W.
# itercount = 3 count = 13
# Position after move relative is 104.97810218978103
# Current power is 1.86316562e-08 W.
# itercount = 3 count = 14
# Position after move relative is 105.84671532846716
# Current power is 1.93569711e-08 W.
# itercount = 3 count = 15
# Position after move relative is 106.71532846715328
# Current power is 1.92343634e-08 W.
# itercount = 3 count = 16
# Position after move relative is 107.58394160583941
# Current power is 1.91725604e-08 W.
# itercount = 3 count = 17
# Position after move relative is 108.45255474452556
# Current power is 1.92364258e-08 W.
# itercount = 3 count = 18
# Position after move relative is 109.32116788321169
# Current power is 1.78239219e-08 W.
# itercount = 3 count = 19
# Position after move relative is 110.18978102189782
# Current power is 1.87789837e-08 W.
# itercount = 3 count = 20
# Position after move relative is 110.93430656934306
# Current power is 1.74396231e-08 W.
# itercount = 3 count = 21
# Position after move relative is 111.8029197080292
# Current power is 1.86625631e-08 W.
# itercount = 3 count = 22
# Position after move relative is 112.67153284671534
# Current power is 1.84328215e-08 W.
# itercount = 3 count = 23
# Position after move relative is 113.54014598540147
# Current power is 1.8177305e-08 W.
# itercount = 3 count = 24
# Position after move relative is 114.4087591240876
# Current power is 1.79599091e-08 W.
# itercount = 4 count = 0
# Position after move relative is 97.16058394160584
# Current power is 1.85945606e-08 W.
# itercount = 4 count = 1
# Position after move relative is 97.65693430656934
# Current power is 1.85183282e-08 W.
# itercount = 4 count = 2
# Position after move relative is 98.02919708029198
# Current power is 1.86563849e-08 W.
# itercount = 4 count = 3
# Position after move relative is 98.4014598540146
# Current power is 1.86945073e-08 W.
# itercount = 4 count = 4
# Position after move relative is 98.89781021897811
# Current power is 1.8174207e-08 W.
# itercount = 4 count = 5
# Position after move relative is 99.27007299270073
# Current power is 1.88717149e-08 W.
# itercount = 4 count = 6
# Position after move relative is 99.76642335766424
# Current power is 1.90468565e-08 W.
# itercount = 4 count = 7
# Position after move relative is 100.13868613138686
# Current power is 1.88078388e-08 W.
# itercount = 4 count = 8
# Position after move relative is 100.63503649635037
# Current power is 1.89603249e-08 W.
# itercount = 4 count = 9
# Position after move relative is 101.00729927007299
# Current power is 1.8424565e-08 W.
# itercount = 4 count = 10
# Position after move relative is 101.37956204379562
# Current power is 1.85719031e-08 W.
# itercount = 4 count = 11
# Position after move relative is 101.87591240875912
# Current power is 1.93075227e-08 W.
# itercount = 4 count = 12
# Position after move relative is 102.24817518248176
# Current power is 1.93580068e-08 W.
# itercount = 4 count = 13
# Position after move relative is 102.74452554744526
# Current power is 1.92766141e-08 W.
# itercount = 4 count = 14
# Position after move relative is 103.11678832116789
# Current power is 1.9073644e-08 W.
# itercount = 4 count = 15
# Position after move relative is 103.61313868613139
# Current power is 1.88356637e-08 W.
# itercount = 4 count = 16
# Position after move relative is 103.98540145985402
# Current power is 1.93477057e-08 W.
# itercount = 4 count = 17
# Position after move relative is 104.35766423357664
# Current power is 1.93765501e-08 W.
# itercount = 4 count = 18
# Position after move relative is 104.85401459854015
# Current power is 1.94816412e-08 W.
# itercount = 4 count = 19
# Position after move relative is 105.22627737226277
# Current power is 1.92951628e-08 W.
# itercount = 4 count = 20
# Position after move relative is 105.72262773722628
# Current power is 1.93713934e-08 W.
# itercount = 4 count = 21
# Position after move relative is 106.09489051094891
# Current power is 1.88305016e-08 W.
# itercount = 4 count = 22
# Position after move relative is 106.5912408759124
# Current power is 1.73623445e-08 W.
# itercount = 4 count = 23
# Position after move relative is 106.96350364963504
# Current power is 1.92127345e-08 W.
# itercount = 4 count = 24
# Position after move relative is 107.33576642335767
# Current power is 1.93013339e-08 W.
# itercount = 5 count = 0
# Position after move relative is 102.24817518248176
# Current power is 1.89891587e-08 W.
# itercount = 5 count = 1
# Position after move relative is 102.37226277372262
# Current power is 1.77260286e-08 W.
# itercount = 5 count = 2
# Position after move relative is 102.62043795620438
# Current power is 1.92127345e-08 W.
# itercount = 5 count = 3
# Position after move relative is 102.86861313868613
# Current power is 1.9134438e-08 W.
# itercount = 5 count = 4
# Position after move relative is 102.99270072992701
# Current power is 1.94208525e-08 W.
# itercount = 5 count = 5
# Position after move relative is 103.24087591240877
# Current power is 1.87861939e-08 W.
# itercount = 5 count = 6
# Position after move relative is 103.48905109489051
# Current power is 1.88521323e-08 W.
# itercount = 5 count = 7
# Position after move relative is 103.73722627737227
# Current power is 1.771574e-08 W.
# itercount = 5 count = 8
# Position after move relative is 103.86131386861314
# Current power is 1.92889775e-08 W.
# itercount = 5 count = 9
# Position after move relative is 104.1094890510949
# Current power is 1.94363139e-08 W.
# itercount = 5 count = 10
# Position after move relative is 104.35766423357664
# Current power is 1.93384295e-08 W.
# itercount = 5 count = 11
# Position after move relative is 104.48175182481752
# Current power is 1.9279712e-08 W.
# itercount = 5 count = 12
# Position after move relative is 104.72992700729927
# Current power is 1.79702138e-08 W.
# itercount = 5 count = 13
# Position after move relative is 104.97810218978103
# Current power is 1.93806695e-08 W.
# itercount = 5 count = 14
# Position after move relative is 105.22627737226277
# Current power is 1.93950935e-08 W.
# itercount = 5 count = 15
# Position after move relative is 105.35036496350365
# Current power is 1.94466114e-08 W.
# itercount = 5 count = 16
# Position after move relative is 105.59854014598541
# Current power is 1.93363743e-08 W.
# itercount = 5 count = 17
# Position after move relative is 105.84671532846716
# Current power is 1.81989357e-08 W.
# itercount = 5 count = 18
# Position after move relative is 105.97080291970804
# Current power is 1.75663502e-08 W.
# itercount = 5 count = 19
# Position after move relative is 106.21897810218978
# Current power is 1.92982483e-08 W.
# itercount = 5 count = 20
# Position after move relative is 106.46715328467154
# Current power is 1.91323704e-08 W.
# itercount = 5 count = 21
# Position after move relative is 106.71532846715328
# Current power is 1.90633429e-08 W.
# itercount = 5 count = 22
# Position after move relative is 106.83941605839416
# Current power is 1.93260679e-08 W.
# itercount = 5 count = 23
# Position after move relative is 107.08759124087591
# Current power is 1.91251637e-08 W.
# itercount = 5 count = 24
# Position after move relative is 107.33576642335767
# Current power is 1.91838812e-08 W.
# converged to max power.
# paddle = c_ushort(1) final_angle = 170.0
# paddle = c_ushort(3) final_angle = 170.0
# paddle = c_ushort(2) final_angle = 107.45985401459855

# %%
pol_paddle.close()
